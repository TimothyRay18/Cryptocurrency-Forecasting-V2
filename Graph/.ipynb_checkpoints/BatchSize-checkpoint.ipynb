# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
btc = ['LSTM BTC', 'BiLSTM BTC']
btc1 = [412.92, 658.46]
btc2 = [336.11, 867.26]
btc3 = [724.01, 756.32]

eth = ['LSTM ETH', 'BiLSTM ETH']
eth1 = [23.823, 26.577]
eth2 = [54.078, 85.917]
eth3 = [35.180, 47.510]

ltc = ['LSTM LTC', 'BiLSTM LTC']
ltc1 = [0.644, 0.703]
ltc2 = [0.799, 0.877]
ltc3 = [2.441, 3.886]

# Positions of bars on x-axis
x = np.arange(len(btc))

# Width of bars
width = 0.2

fig, axs = plt.subplots(ncols=3, nrows=3)
fig.set_figwidth(12)
fig.set_figheight(12)
axs[0,0].bar(x - width, btc1, width, label='Batch size 32')
axs[0,0].bar(x, btc2, width, label='Batch size 64')
axs[0,0].bar(x + width, btc3, width, label='Batch size 128')
axs[0,0].set_xticks(x)
axs[0,0].set_xticklabels(btc)

axs[0,1].bar(x - width, eth1, width)
axs[0,1].bar(x, eth2, width)
axs[0,1].bar(x + width, eth3, width)
axs[0,1].set_xticks(x)
axs[0,1].set_xticklabels(eth)

axs[0,2].bar(x - width, ltc1, width)
axs[0,2].bar(x, ltc2, width)
axs[0,2].bar(x + width, ltc3, width)
axs[0,2].set_xticks(x)
axs[0,2].set_xticklabels(ltc)
axs[0,0].set_ylabel('RMSE')

# Adding legend
fig.legend(loc='lower center', ncol=3, bbox_to_anchor=(0.5, 0.05))

# fig.suptitle('Perbandingan RMSE BTC, ETH, dan LTC Berdasarkan Batch Size', fontsize=16)
for row in axs:
    for ax in row:
        for rect in ax.containers:
            ax.bar_label(rect, label_type='edge')
        
# Data
btc = ['LSTM BTC', 'BiLSTM BTC']
btc1 = [393.71, 311.44]
btc2 = [328.85, 308.64]
btc3 = [884.18, 587.679]

eth = ['LSTM ETH', 'BiLSTM ETH']
eth1 = [13.785, 16.568]
eth2 = [38.768, 36.685]
eth3 = [29.336, 26.550]

ltc = ['LSTM LTC', 'BiLSTM LTC']
ltc1 = [0.506, 0.527]
ltc2 = [0.619, 0.642]
ltc3 = [3.007, 2.770]

# Positions of bars on x-axis
x = np.arange(len(btc))

axs[1,0].bar(x - width, btc1, width)
axs[1,0].bar(x, btc2, width)
axs[1,0].bar(x + width, btc3, width)
axs[1,0].set_xticks(x)
axs[1,0].set_xticklabels(btc)

axs[1,1].bar(x - width, eth1, width)
axs[1,1].bar(x, eth2, width)
axs[1,1].bar(x + width, eth3, width)
axs[1,1].set_xticks(x)
axs[1,1].set_xticklabels(eth)

axs[1,2].bar(x - width, ltc1, width)
axs[1,2].bar(x, ltc2, width)
axs[1,2].bar(x + width, ltc3, width)
axs[1,2].set_xticks(x)
axs[1,2].set_xticklabels(ltc)
axs[1,0].set_ylabel('MAE')

# fig.suptitle('Perbandingan BTC, ETH, dan LTC Berdasarkan Batch Size', fontsize=16)

for row in axs:
    for ax in row:
        for rect in ax.containers:
            ax.bar_label(rect, label_type='edge')
            
x = np.arange(len(btc))

# Data
btc = ['LSTM BTC', 'BiLSTM BTC']
btc1 = [2.037, 1.584]
btc2 = [1.715, 1.604]
btc3 = [4.352, 2.890]

eth = ['LSTM ETH', 'BiLSTM ETH']
eth1 = [0.974, 1.189]
eth2 = [2.993, 2.809]
eth3 = [2.259, 2.029]

ltc = ['LSTM LTC', 'BiLSTM LTC']
ltc1 = [0.851, 0.884]
ltc2 = [1.053, 1.087]
ltc3 = [5.284, 4.843]

axs[2,0].bar(x - width, btc1, width)
axs[2,0].bar(x, btc2, width)
axs[2,0].bar(x + width, btc3, width)
axs[2,0].set_xticks(x)
axs[2,0].set_xticklabels(btc)

axs[2,1].bar(x - width, eth1, width)
axs[2,1].bar(x, eth2, width)
axs[2,1].bar(x + width, eth3, width)
axs[2,1].set_xticks(x)
axs[2,1].set_xticklabels(eth)

axs[2,2].bar(x - width, ltc1, width)
axs[2,2].bar(x, ltc2, width)
axs[2,2].bar(x + width, ltc3, width)
axs[2,2].set_xticks(x)
axs[2,2].set_xticklabels(ltc)
axs[2,0].set_ylabel('MAE')

# fig.suptitle('Perbandingan MAPE BTC, ETH, dan LTC Berdasarkan Batch Size', fontsize=16)

for row in axs:
    for ax in row:
        for rect in ax.containers:
            ax.bar_label(rect, label_type='edge')

# plt.show()
fig.savefig('../../Skripsi/img/batchSizeCompare.png', dpi=300)

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, axs = plt.subplots(ncols=2, nrows=3)
fig.set_figwidth(12)
fig.set_figheight(12)

# Generate some sample data
bs_32_ls_btc = [1.7644, 1.4150, 2.0314, 1.7356, 1.6931, 2.0142, 1.5815, 1.7885, 2.2618]
bs_64_ls_btc = [1.5929, 1.6193, 1.9715, 1.3788, 1.4113, 1.3411, 1.4832, 1.2108, 1.5592]
bs_128_ls_btc = [9.3429, 1.2676, 1.4442, 3.6767, 2.7859, 4.3719, 2.5373, 1.2591, 1.4304]
bs_32_bi_btc = [3.0867, 1.8444, 2.2178, 4.6807, 1.8002, 4.4039, 3.3618, 3.0228, 3.0935]
bs_64_bi_btc = [12.3301, 1.8678, 1.6271, 10.1023, 1.9572, 1.5214, 6.1838, 1.1132, 1.1425]
bs_128_bi_btc = [5.4680, 2.7561, 1.9688, 2.4432, 2.5033, 3.6698, 2.5670, 1.8637, 3.0992]
bs_32_ls_eth = [1.7201, 1.9424, 2.6170, 1.5181, 1.2603, 1.1908, 1.3160, 0.7940, 0.8515]
bs_64_ls_eth = [3.4809, 3.5112, 3.7709, 2.9930, 3.0256, 3.2397, 7.7689, 2.5785, 4.0574]
bs_128_ls_eth = [3.3027, 2.6322, 3.6167, 2.8217, 2.0885, 1.8817, 0.9701, 2.3414, 1.4958]
bs_32_bi_eth = [2.2178, 2.0269, 2.8810, 1.4431, 1.1757, 2.3862, 0.9870, 0.8754, 0.8789]
bs_64_bi_eth = [7.9745, 4.5043, 3.6555, 9.1499, 3.4271, 8.7700, 7.0697, 7.2301, 3.7472]
bs_128_bi_eth = [4.5336, 4.0671, 5.3520, 3.3569, 3.4855, 3.4343, 1.7115, 1.3516, 1.9430]
bs_32_ls_ltc = [0.8387, 0.7583, 0.8687, 0.7519, 0.6906, 0.8004, 0.6613, 0.6394, 0.7215]
bs_64_ls_ltc = [1.0998, 1.2935, 0.9327, 0.9455, 0.8971, 1.0703, 1.1644, 0.8801, 0.8661]
bs_128_ls_ltc = [6.9682, 9.1008, 0.8588, 8.0192, 0.8195, 0.8078, 4.2057, 4.3015, 0.7764]
bs_32_bi_ltc = [1.0168, 0.8321, 0.8550, 0.9887, 0.7690, 0.6652, 0.9683, 0.6869, 0.8614]
bs_64_bi_ltc = [1.0218, 1.0622, 0.9340, 1.4495, 1.5910, 0.9553, 1.3442, 0.9340, 0.9168]
bs_128_bi_ltc = [9.8630, 13.5934, 12.3241, 6.1555, 0.8740, 5.5022, 3.3681, 3.8822, 3.5843]

# Combine the data into a list
data1 = [bs_32_ls_btc, bs_64_ls_btc, bs_128_ls_btc]
data2 = [bs_32_bi_btc, bs_64_bi_btc, bs_128_bi_btc]
data3 = [bs_32_ls_eth, bs_64_ls_eth, bs_128_ls_eth]
data4 = [bs_32_bi_eth, bs_64_bi_eth, bs_128_bi_eth]
data5 = [bs_32_ls_ltc, bs_64_ls_ltc, bs_128_ls_ltc]
data6 = [bs_32_bi_ltc, bs_64_bi_ltc, bs_128_bi_ltc]
labels = ['32', '64', '128']

axs[0,0].boxplot(data1, labels=labels)
axs[0,1].boxplot(data2, labels=labels)
axs[1,0].boxplot(data3, labels=labels)
axs[1,1].boxplot(data4, labels=labels)
axs[2,0].boxplot(data5, labels=labels)
axs[2,1].boxplot(data6, labels=labels)

# Set the title and axis labels
# ax.set_title('Boxplot Perbandingan MAPE')
ax.set_xlabel('Batch Size')
ax.set_ylabel('MAPE')
axs[2,0].set_xlabel('LSTM')
axs[2,1].set_xlabel('BiLSTM')
axs[0,0].set_ylabel('BTC')
axs[1,0].set_ylabel('ETH')
axs[2,0].set_ylabel('LTC')


# Set the title and axis labels
fig.text(0.5, 0.04, 'Batch Size', ha='center', fontsize=12)
fig.text(0.04, 0.5, 'MAPE', va='center', rotation='vertical', fontsize=12)

# Show the plot
plt.show()
fig.savefig('../../Skripsi/img/boxplotMAPECompareSeparate.png', dpi=300)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate some sample data
bs_32 = [1.4150, 1.6931, 1.5815, 1.7356, 1.7644, 1.7885, 1.8002, 1.8444, 2.0142, 2.0314, 2.2178, 2.2618, 3.0228, 3.0935, 3.0867, 3.3618, 4.4039, 4.6807, 1.9424, 1.2603, 1.3160, 1.5181, 1.7201, 0.7940, 1.1757, 2.0269, 1.1908, 2.6170, 2.8810, 0.8515, 0.8754, 0.8789, 2.2178, 0.9870, 2.3862, 1.4431, 0.6906, 0.6613, 0.7519, 0.8387, 0.6394, 0.7690, 0.8321, 0.8004, 0.8687, 0.8550, 0.7215, 0.6869, 0.8614, 1.0168, 0.9683, 0.6652, 0.9887]
bs_64 = [1.1132, 1.1425, 1.2108, 1.3411, 1.3788, 1.4113, 1.4832, 1.5214, 1.5592, 1.5929, 1.6193, 1.6271, 1.9572, 1.8678, 1.9715, 6.1838, 10.1023, 12.3301, 7.2301, 3.7472, 2.5785, 3.2397, 2.9930, 3.0256, 7.7689, 8.7700, 4.0574, 3.4809, 3.5112, 3.6555, 3.4271, 4.5043, 3.7709, 7.0697, 9.1499, 7.9745, 0.9340, 0.9168, 0.8801, 1.0703, 0.9455, 0.8971, 1.1644, 0.9553, 0.8661, 1.0998, 1.2935, 0.9340, 1.5910, 1.0622, 0.9327, 1.3442, 1.4495, 1.0218]
bs_128 = [1.2591, 1.2676, 1.4442, 1.4304, 1.8637, 2.5373, 1.9688, 2.5670, 2.7859, 2.5033, 2.4432, 2.7561, 3.0992, 3.6767, 3.6698, 4.3719, 5.4680, 9.3429, 2.3414, 2.6322, 3.6167, 1.4958, 1.3516, 0.9701, 5.3520, 1.7115, 2.0885, 3.4855, 3.3569, 4.0671, 1.9430, 2.8217, 3.4343, 1.8817, 4.5336, 3.3027, 4.3015, 9.1008, 0.8588, 0.7764, 3.8822, 4.2057, 12.3241, 3.3681, 0.8195, 0.8740, 6.1555, 13.5934, 3.5843, 8.0192, 5.5022, 0.8078, 9.8630, 6.9682]

# Combine the data into a list
data = [bs_32, bs_64, bs_128]

labels = ['32', '64', '128']
fig, ax = plt.subplots()
ax.boxplot(data, labels=labels)

# Set the title and axis labels
# ax.set_title('Boxplot Perbandingan MAPE')
ax.set_xlabel('Batch Size')
ax.set_ylabel('MAPE')

# Show the plot
plt.show()
fig.savefig('../../Skripsi/img/boxplotMAPECompare.png', dpi=300)

# %%
max(bs_32)-min(bs_32)
# Out:
# 4.0413

# %%
max(bs_64)-min(bs_64)
# Out:
# 11.464

# %%
max(bs_128)-min(bs_128)
# Out:
# 12.817

# %%
import pickle

# %%
with open('../Model LSTM BTC/LSTM_BTC(32, 100, 60).pkl', "rb") as file_pi:
    lstm_btc32 = pickle.load(file_pi)
with open('../Model LSTM BTC/LSTM_BTC(64, 100, 60).pkl', "rb") as file_pi:
    lstm_btc64 = pickle.load(file_pi)
with open('../Model LSTM BTC/LSTM_BTC(128, 100, 60).pkl', "rb") as file_pi:
    lstm_btc128 = pickle.load(file_pi)
with open('../Model BiLSTM BTC/BiLSTM_BTC(32, 100, 60).pkl', "rb") as file_pi:
    bilstm_btc32 = pickle.load(file_pi)
with open('../Model BiLSTM BTC/BiLSTM_BTC(64, 100, 60).pkl', "rb") as file_pi:
    bilstm_btc64 = pickle.load(file_pi)
with open('../Model BiLSTM BTC/BiLSTM_BTC(128, 100, 60).pkl', "rb") as file_pi:
    bilstm_btc128 = pickle.load(file_pi)
    
fig, axs = plt.subplots(nrows=3, ncols=2)
fig.set_figwidth(12)
fig.set_figheight(12)

labels = ['loss', 'val_loss']

# Plot data for LSTM models
axs[0,0].plot(lstm_btc32['loss'], label='train_loss_32')
axs[0,0].plot(lstm_btc32['val_loss'], label='val_loss_32')
axs[0,0].legend()
axs[1,0].plot(lstm_btc64['loss'], label='train_loss_64', color='red')
axs[1,0].plot(lstm_btc64['val_loss'], label='val_loss_64', color='green')
axs[1,0].legend()
axs[2,0].plot(lstm_btc128['loss'], label='train_loss_128', color='purple')
axs[2,0].plot(lstm_btc128['val_loss'], label='val_loss_128', color='brown')
axs[2,0].legend()

# Plot data for BiLSTM models
axs[0,1].plot(bilstm_btc32['loss'], label='train_loss_32')
axs[0,1].plot(bilstm_btc32['val_loss'], label='val_loss_32')
axs[0,1].legend()
axs[1,1].plot(bilstm_btc64['loss'], label='train_loss_64', color='red')
axs[1,1].plot(bilstm_btc64['val_loss'], label='val_loss_64', color='green')
axs[1,1].legend()
axs[2,1].plot(bilstm_btc128['loss'], label='train_loss_128', color='purple')
axs[2,1].plot(bilstm_btc128['val_loss'], label='val_loss_128',color='brown')
axs[2,1].legend()

# Set the y-axis labels
axs[0,0].set_ylabel('MSE')
axs[1,0].set_ylabel('MSE')
axs[2,0].set_ylabel('MSE')

# Set the x-axis labels
axs[2,0].set_xlabel('LSTM')
axs[2,1].set_xlabel('BiLSTM')

# Set the title and axis labels
fig.text(0.5, 0.04, 'Epochs', ha='center', fontsize=12)
fig.text(0.04, 0.5, 'Loss', va='center', rotation='vertical', fontsize=12)

# Show the plot
# ymin, ymax = 0, 0.005
# for ax in axs.flat:
#     ax.set_ylim([ymin, ymax])
# Show the plot
plt.show()
fig.savefig('../../Skripsi/img/curveMSEBTC.png', dpi=300)

# %%
with open('../Model LSTM ETH/LSTM_ETH(32, 100, 60).pkl', "rb") as file_pi:
    lstm_eth32 = pickle.load(file_pi)
with open('../Model LSTM ETH/LSTM_ETH(64, 100, 60).pkl', "rb") as file_pi:
    lstm_eth64 = pickle.load(file_pi)
with open('../Model LSTM ETH/LSTM_ETH(128, 100, 60).pkl', "rb") as file_pi:
    lstm_eth128 = pickle.load(file_pi)
with open('../Model BiLSTM ETH/BiLSTM_ETH(32, 100, 60).pkl', "rb") as file_pi:
    bilstm_eth32 = pickle.load(file_pi)
with open('../Model BiLSTM ETH/BiLSTM_ETH(64, 100, 60).pkl', "rb") as file_pi:
    bilstm_eth64 = pickle.load(file_pi)
with open('../Model BiLSTM ETH/BiLSTM_ETH(128, 100, 60).pkl', "rb") as file_pi:
    bilstm_eth128 = pickle.load(file_pi)
    
fig, axs = plt.subplots(nrows=3, ncols=2)
fig.set_figwidth(12)
fig.set_figheight(12)

labels = ['loss', 'val_loss']

# Plot data for LSTM models
axs[0,0].plot(lstm_eth32['loss'], label='train_loss_32')
axs[0,0].plot(lstm_eth32['val_loss'], label='val_loss_32')
axs[0,0].legend()
axs[1,0].plot(lstm_eth64['loss'], label='train_loss_64', color='red')
axs[1,0].plot(lstm_eth64['val_loss'], label='val_loss_64', color='green')
axs[1,0].legend()
axs[2,0].plot(lstm_eth128['loss'], label='train_loss_128', color='purple')
axs[2,0].plot(lstm_eth128['val_loss'], label='val_loss_128', color='brown')
axs[2,0].legend()

# Plot data for BiLSTM models
axs[0,1].plot(bilstm_eth32['loss'], label='train_loss_32')
axs[0,1].plot(bilstm_eth32['val_loss'], label='val_loss_32')
axs[0,1].legend()
axs[1,1].plot(bilstm_eth64['loss'], label='train_loss_64', color='red')
axs[1,1].plot(bilstm_eth64['val_loss'], label='val_loss_64', color='green')
axs[1,1].legend()
axs[2,1].plot(bilstm_eth128['loss'], label='train_loss_128', color='purple')
axs[2,1].plot(bilstm_eth128['val_loss'], label='val_loss_128',color='brown')
axs[2,1].legend()

# Set the y-axis labels
axs[0,0].set_ylabel('MSE')
axs[1,0].set_ylabel('MSE')
axs[2,0].set_ylabel('MSE')

# Set the x-axis labels
axs[2,0].set_xlabel('LSTM')
axs[2,1].set_xlabel('BiLSTM')

# Set the title and axis labels
fig.text(0.5, 0.04, 'Epochs', ha='center', fontsize=12)
fig.text(0.04, 0.5, 'Loss', va='center', rotation='vertical', fontsize=12)

# Show the plot
plt.show()

# Show the plot
plt.show()
fig.savefig('../../Skripsi/img/curveMSEETH.png', dpi=300)

# %%
with open('../Model LSTM LTC/LSTM_LTC(32, 100, 60).pkl', "rb") as file_pi:
    lstm_ltc32 = pickle.load(file_pi)
with open('../Model LSTM LTC/LSTM_LTC(64, 100, 60).pkl', "rb") as file_pi:
    lstm_ltc64 = pickle.load(file_pi)
with open('../Model LSTM LTC/LSTM_LTC(128, 100, 60).pkl', "rb") as file_pi:
    lstm_ltc128 = pickle.load(file_pi)
with open('../Model BiLSTM LTC/BiLSTM_LTC(32, 100, 60).pkl', "rb") as file_pi:
    bilstm_ltc32 = pickle.load(file_pi)
with open('../Model BiLSTM LTC/BiLSTM_LTC(64, 100, 60).pkl', "rb") as file_pi:
    bilstm_ltc64 = pickle.load(file_pi)
with open('../Model BiLSTM LTC/BiLSTM_LTC(128, 100, 60).pkl', "rb") as file_pi:
    bilstm_ltc128 = pickle.load(file_pi)
    
fig, axs = plt.subplots(nrows=3, ncols=2)
fig.set_figwidth(12)
fig.set_figheight(12)

labels = ['loss', 'val_loss']

# Plot data for LSTM models
axs[0,0].plot(lstm_ltc32['loss'], label='train_loss_32')
axs[0,0].plot(lstm_ltc32['val_loss'], label='val_loss_32')
axs[0,0].legend()
axs[1,0].plot(lstm_ltc64['loss'], label='train_loss_64', color='red')
axs[1,0].plot(lstm_ltc64['val_loss'], label='val_loss_64', color='green')
axs[1,0].legend()
axs[2,0].plot(lstm_ltc128['loss'], label='train_loss_128', color='purple')
axs[2,0].plot(lstm_ltc128['val_loss'], label='val_loss_128', color='brown')
axs[2,0].legend()

# Plot data for BiLSTM models
axs[0,1].plot(bilstm_ltc32['loss'], label='train_loss_32')
axs[0,1].plot(bilstm_ltc32['val_loss'], label='val_loss_32')
axs[0,1].legend()
axs[1,1].plot(bilstm_ltc64['loss'], label='train_loss_64', color='red')
axs[1,1].plot(bilstm_ltc64['val_loss'], label='val_loss_64', color='green')
axs[1,1].legend()
axs[2,1].plot(bilstm_ltc128['loss'], label='train_loss_128', color='purple')
axs[2,1].plot(bilstm_ltc128['val_loss'], label='val_loss_128',color='brown')
axs[2,1].legend()

# Set the y-axis labels
axs[0,0].set_ylabel('MSE')
axs[1,0].set_ylabel('MSE')
axs[2,0].set_ylabel('MSE')

# Set the x-axis labels
axs[2,0].set_xlabel('LSTM')
axs[2,1].set_xlabel('BiLSTM')

# Set the title and axis labels
fig.text(0.5, 0.04, 'Epochs', ha='center', fontsize=12)
fig.text(0.04, 0.5, 'Loss', va='center', rotation='vertical', fontsize=12)

# Show the plot
plt.show()

# Show the plot
plt.show()
fig.savefig('../../Skripsi/img/curveMSELTC.png', dpi=300)
