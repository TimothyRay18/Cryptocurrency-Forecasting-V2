# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

# Data
lstmbtc_32_n_50 = [1.7644, 1.7356, 1.5815]
lstmbtc_32_n_60 = [1.4150, 1.6931, 1.7885]
lstmbtc_32_n_100 = [2.0314, 2.0142, 2.2618]
lstmbtc_64_n_50 = [1.5929, 1.3788, 1.4832]
lstmbtc_64_n_60 = [1.6193, 1.4113, 1.2108]
lstmbtc_64_n_100 = [1.9715, 1.3411, 1.5592]
lstmbtc_128_n_50 = [9.3429, 3.6767, 2.5373]
lstmbtc_128_n_60 = [1.2676, 2.7859, 1.2591]
lstmbtc_128_n_100 = [1.4442, 4.3719, 1.4304]

lstmeth_32_n_50 = [1.7201, 1.5181, 1.3160]
lstmeth_32_n_60 = [1.9424, 1.2603, 0.7940]
lstmeth_32_n_100 = [2.6170, 1.1908, 0.8515]
lstmeth_64_n_50 = [3.4809, 2.9930, 7.7689]
lstmeth_64_n_60 = [3.5112, 3.0256, 2.5785]
lstmeth_64_n_100 = [3.7709, 3.2397, 4.0574]
lstmeth_128_n_50 = [3.3027, 2.8217, 0.9701]
lstmeth_128_n_60 =  [2.6322, 2.0885, 2.3414]
lstmeth_128_n_100 = [3.6167, 1.8817, 1.4958]

lstmltc_32_n_50 = [0.8387, 0.7519, 0.6613]
lstmltc_32_n_60 = [0.7583, 0.6906, 0.6394]
lstmltc_32_n_100 = [0.8687, 0.8004, 0.7215]
lstmltc_64_n_50 = [1.0998, 0.9455, 1.1644]
lstmltc_64_n_60 = [1.2935, 0.8971, 0.8801]
lstmltc_64_n_100 = [0.9327, 1.0703, 0.8661]
lstmltc_128_n_50 = [6.9682, 8.0192, 4.2057]
lstmltc_128_n_60 =  [9.1008, 0.8195, 4.3015]
lstmltc_128_n_100 = [0.8588, 0.8078, 0.7764]

# Figure and axis
fig, axs = plt.subplots(ncols=3, nrows=3)
fig.set_figwidth(12)
fig.set_figheight(8)

# Set axis labels and title
axs[2,0].set_xlabel('Unit')
axs[2,1].set_xlabel('Unit')
axs[2,2].set_xlabel('Unit')
axs[0,0].set_ylabel('MAPE (BTC)')
axs[1,0].set_ylabel('MAPE (ETH)')
axs[2,0].set_ylabel('MAPE (LTC)')

# Set x-tick labels and positions
x_labels = ['50', '60', '100']
x_positions = [1, 2, 3]
axs[0,0].set_xticks(x_positions)
axs[0,0].set_xticklabels(x_labels)
axs[0,1].set_xticks(x_positions)
axs[0,1].set_xticklabels(x_labels)
axs[0,2].set_xticks(x_positions)
axs[0,2].set_xticklabels(x_labels)
axs[1,0].set_xticks(x_positions)
axs[1,0].set_xticklabels(x_labels)
axs[1,1].set_xticks(x_positions)
axs[1,1].set_xticklabels(x_labels)
axs[1,2].set_xticks(x_positions)
axs[1,2].set_xticklabels(x_labels)
axs[2,0].set_xticks(x_positions)
axs[2,0].set_xticklabels(x_labels)
axs[2,1].set_xticks(x_positions)
axs[2,1].set_xticklabels(x_labels)
axs[2,2].set_xticks(x_positions)
axs[2,2].set_xticklabels(x_labels)

# Plot the data vertically
axs[0,0].plot([1]*len(lstmbtc_32_n_50), lstmbtc_32_n_50, 'o', alpha=0.5, markersize=10)
axs[0,0].plot([2]*len(lstmbtc_32_n_50), lstmbtc_32_n_60, 'o', alpha=0.5, markersize=10)
axs[0,0].plot([3]*len(lstmbtc_32_n_50), lstmbtc_32_n_100, 'o', alpha=0.5, markersize=10)
axs[0,1].plot([1]*len(lstmbtc_32_n_50), lstmbtc_64_n_50, 'o', alpha=0.5, markersize=10)
axs[0,1].plot([2]*len(lstmbtc_32_n_50), lstmbtc_64_n_60, 'o', alpha=0.5, markersize=10)
axs[0,1].plot([3]*len(lstmbtc_32_n_50), lstmbtc_64_n_100, 'o', alpha=0.5, markersize=10)
axs[0,2].plot([1]*len(lstmbtc_32_n_50), lstmbtc_128_n_50, 'o', alpha=0.5, markersize=10)
axs[0,2].plot([2]*len(lstmbtc_32_n_50), lstmbtc_128_n_60, 'o', alpha=0.5, markersize=10)
axs[0,2].plot([3]*len(lstmbtc_32_n_50), lstmbtc_128_n_100, 'o', alpha=0.5, markersize=10)

axs[1,0].plot([1]*len(lstmeth_32_n_50), lstmeth_32_n_50, 'o', alpha=0.5, markersize=10)
axs[1,0].plot([2]*len(lstmeth_32_n_50), lstmeth_32_n_60, 'o', alpha=0.5, markersize=10)
axs[1,0].plot([3]*len(lstmeth_32_n_50), lstmeth_32_n_100, 'o', alpha=0.5, markersize=10)
axs[1,1].plot([1]*len(lstmeth_32_n_50), lstmeth_64_n_50, 'o', alpha=0.5, markersize=10)
axs[1,1].plot([2]*len(lstmeth_32_n_50), lstmeth_64_n_60, 'o', alpha=0.5, markersize=10)
axs[1,1].plot([3]*len(lstmeth_32_n_50), lstmeth_64_n_100, 'o', alpha=0.5, markersize=10)
axs[1,2].plot([1]*len(lstmeth_32_n_50), lstmeth_128_n_50, 'o', alpha=0.5, markersize=10)
axs[1,2].plot([2]*len(lstmeth_32_n_50), lstmeth_128_n_60, 'o', alpha=0.5, markersize=10)
axs[1,2].plot([3]*len(lstmeth_32_n_50), lstmeth_128_n_100, 'o', alpha=0.5, markersize=10)

axs[2,0].plot([1]*len(lstmltc_32_n_50), lstmltc_32_n_50, 'o', alpha=0.5, markersize=10)
axs[2,0].plot([2]*len(lstmltc_32_n_50), lstmltc_32_n_60, 'o', alpha=0.5, markersize=10)
axs[2,0].plot([3]*len(lstmltc_32_n_50), lstmltc_32_n_100, 'o', alpha=0.5, markersize=10)
axs[2,1].plot([1]*len(lstmltc_32_n_50), lstmltc_64_n_50, 'o', alpha=0.5, markersize=10)
axs[2,1].plot([2]*len(lstmltc_32_n_50), lstmltc_64_n_60, 'o', alpha=0.5, markersize=10)
axs[2,1].plot([3]*len(lstmltc_32_n_50), lstmltc_64_n_100, 'o', alpha=0.5, markersize=10)
axs[2,2].plot([1]*len(lstmltc_32_n_50), lstmltc_128_n_50, 'o', alpha=0.5, markersize=10)
axs[2,2].plot([2]*len(lstmltc_32_n_50), lstmltc_128_n_60, 'o', alpha=0.5, markersize=10)
axs[2,2].plot([3]*len(lstmltc_32_n_50), lstmltc_128_n_100, 'o', alpha=0.5, markersize=10)

# Connect the dots
for i in range(len(lstmbtc_32_n_50)):
    axs[0,0].plot([1, 2, 3], [lstmbtc_32_n_50[i], lstmbtc_32_n_60[i], lstmbtc_32_n_100[i]], '-')
    axs[0,1].plot([1, 2, 3], [lstmbtc_64_n_50[i], lstmbtc_64_n_60[i], lstmbtc_64_n_100[i]], '-')
    axs[0,2].plot([1, 2, 3], [lstmbtc_128_n_50[i], lstmbtc_128_n_60[i], lstmbtc_128_n_100[i]], '-')
    axs[1,0].plot([1, 2, 3], [lstmeth_32_n_50[i], lstmeth_32_n_60[i], lstmeth_32_n_100[i]], '-')
    axs[1,1].plot([1, 2, 3], [lstmeth_64_n_50[i], lstmeth_64_n_60[i], lstmeth_64_n_100[i]], '-')
    axs[1,2].plot([1, 2, 3], [lstmeth_128_n_50[i], lstmeth_128_n_60[i], lstmeth_128_n_100[i]], '-')
    axs[2,0].plot([1, 2, 3], [lstmltc_32_n_50[i], lstmltc_32_n_60[i], lstmltc_32_n_100[i]], '-')
    axs[2,1].plot([1, 2, 3], [lstmltc_64_n_50[i], lstmltc_64_n_60[i], lstmltc_64_n_100[i]], '-')
    axs[2,2].plot([1, 2, 3], [lstmltc_128_n_50[i], lstmltc_128_n_60[i], lstmltc_128_n_100[i]], '-')
    
labels = ['epoch 25', 'epoch 50', 'epoch 100']

# Create a list of the line objects in your figure
lines = [axs[0,0], axs[0,0].lines[1], axs[0,0].lines[2]]

# Create the legend
red_line = Line2D([0], [0], color='red', lw=1)
purple_line = Line2D([0], [0], color='purple', lw=1)
brown_line = Line2D([0], [0], color='brown', lw=1)
fig.legend([red_line, purple_line, brown_line], ['epoch 25', 'epoch 50', 'epoch 100'],loc='center', bbox_to_anchor=(0.5, 0), ncol=3)

# Show the plot
plt.show()
fig.savefig('../../Skripsi/img/lstmUnitCompare.png', dpi=300)

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

# Data
bilstmbtc_32_n_50 = [3.0867, 4.6807, 3.3618]
bilstmbtc_32_n_60 = [1.8444, 1.8002, 3.0228]
bilstmbtc_32_n_100 = [2.2178, 4.4039, 3.0935]
bilstmbtc_64_n_50 = [12.3301, 10.1023, 6.1838]
bilstmbtc_64_n_60 = [1.8678, 1.9572, 1.1132]
bilstmbtc_64_n_100 = [1.6271, 1.5214, 1.1425]
bilstmbtc_128_n_50 = [5.4680, 2.4432, 2.5670]
bilstmbtc_128_n_60 = [2.7561, 2.5033, 1.8637]
bilstmbtc_128_n_100 = [1.9688, 3.6698, 3.0992]

bilstmeth_32_n_50 = [2.2178, 1.4431, 0.9870]
bilstmeth_32_n_60 = [2.0269, 1.1757, 0.8754]
bilstmeth_32_n_100 = [2.8810, 2.3862, 0.8789]
bilstmeth_64_n_50 = [7.9745, 9.1499, 7.0697]
bilstmeth_64_n_60 = [4.5043, 3.4271, 7.2301]
bilstmeth_64_n_100 = [3.6555, 8.7700, 3.7472]
bilstmeth_128_n_50 = [4.5336, 3.3569, 1.7115]
bilstmeth_128_n_60 =  [4.0671, 3.4855, 1.3516]
bilstmeth_128_n_100 = [5.3520, 3.4343, 1.9430]

bilstmltc_32_n_50 = [1.0168, 0.9887, 0.9683]
bilstmltc_32_n_60 = [0.8321, 0.7690, 0.6869]
bilstmltc_32_n_100 = [0.8550, 0.6652, 0.8614]
bilstmltc_64_n_50 = [1.0218, 1.4495, 1.3442]
bilstmltc_64_n_60 = [1.0622, 1.5910, 0.9340]
bilstmltc_64_n_100 = [0.9340, 0.9553, 0.9168]
bilstmltc_128_n_50 =  [9.8630, 6.1555, 3.3681]
bilstmltc_128_n_60 =  [13.5934, 0.8740, 3.8822]
bilstmltc_128_n_100 = [12.3241, 5.5022, 3.5843]

# Figure and axis
fig, axs = plt.subplots(ncols=3, nrows=3)
fig.set_figwidth(12)
fig.set_figheight(8)

# Set axis labels and title
axs[2,0].set_xlabel('Unit')
axs[2,1].set_xlabel('Unit')
axs[2,2].set_xlabel('Unit')
axs[0,0].set_ylabel('MAPE (BTC)')
axs[1,0].set_ylabel('MAPE (ETH)')
axs[2,0].set_ylabel('MAPE (LTC)')

# Set x-tick labels and positions
x_labels = ['50', '60', '100']
x_positions = [1, 2, 3]
axs[0,0].set_xticks(x_positions)
axs[0,0].set_xticklabels(x_labels)
axs[0,1].set_xticks(x_positions)
axs[0,1].set_xticklabels(x_labels)
axs[0,2].set_xticks(x_positions)
axs[0,2].set_xticklabels(x_labels)
axs[1,0].set_xticks(x_positions)
axs[1,0].set_xticklabels(x_labels)
axs[1,1].set_xticks(x_positions)
axs[1,1].set_xticklabels(x_labels)
axs[1,2].set_xticks(x_positions)
axs[1,2].set_xticklabels(x_labels)
axs[2,0].set_xticks(x_positions)
axs[2,0].set_xticklabels(x_labels)
axs[2,1].set_xticks(x_positions)
axs[2,1].set_xticklabels(x_labels)
axs[2,2].set_xticks(x_positions)
axs[2,2].set_xticklabels(x_labels)

# Plot the data vertically
axs[0,0].plot([1]*len(bilstmbtc_32_n_50), bilstmbtc_32_n_50, 'o', alpha=0.5, markersize=10)
axs[0,0].plot([2]*len(bilstmbtc_32_n_50), bilstmbtc_32_n_60, 'o', alpha=0.5, markersize=10)
axs[0,0].plot([3]*len(bilstmbtc_32_n_50), bilstmbtc_32_n_100, 'o', alpha=0.5, markersize=10)
axs[0,1].plot([1]*len(bilstmbtc_32_n_50), bilstmbtc_64_n_50, 'o', alpha=0.5, markersize=10)
axs[0,1].plot([2]*len(bilstmbtc_32_n_50), bilstmbtc_64_n_60, 'o', alpha=0.5, markersize=10)
axs[0,1].plot([3]*len(bilstmbtc_32_n_50), bilstmbtc_64_n_100, 'o', alpha=0.5, markersize=10)
axs[0,2].plot([1]*len(bilstmbtc_32_n_50), bilstmbtc_128_n_50, 'o', alpha=0.5, markersize=10)
axs[0,2].plot([2]*len(bilstmbtc_32_n_50), bilstmbtc_128_n_60, 'o', alpha=0.5, markersize=10)
axs[0,2].plot([3]*len(bilstmbtc_32_n_50), bilstmbtc_128_n_100, 'o', alpha=0.5, markersize=10)

axs[1,0].plot([1]*len(bilstmeth_32_n_50), bilstmeth_32_n_50, 'o', alpha=0.5, markersize=10)
axs[1,0].plot([2]*len(bilstmeth_32_n_50), bilstmeth_32_n_60, 'o', alpha=0.5, markersize=10)
axs[1,0].plot([3]*len(bilstmeth_32_n_50), bilstmeth_32_n_100, 'o', alpha=0.5, markersize=10)
axs[1,1].plot([1]*len(bilstmeth_32_n_50), bilstmeth_64_n_50, 'o', alpha=0.5, markersize=10)
axs[1,1].plot([2]*len(bilstmeth_32_n_50), bilstmeth_64_n_60, 'o', alpha=0.5, markersize=10)
axs[1,1].plot([3]*len(bilstmeth_32_n_50), bilstmeth_64_n_100, 'o', alpha=0.5, markersize=10)
axs[1,2].plot([1]*len(bilstmeth_32_n_50), bilstmeth_128_n_50, 'o', alpha=0.5, markersize=10)
axs[1,2].plot([2]*len(bilstmeth_32_n_50), bilstmeth_128_n_60, 'o', alpha=0.5, markersize=10)
axs[1,2].plot([3]*len(bilstmeth_32_n_50), bilstmeth_128_n_100, 'o', alpha=0.5, markersize=10)

axs[2,0].plot([1]*len(bilstmltc_32_n_50), bilstmltc_32_n_50, 'o', alpha=0.5, markersize=10)
axs[2,0].plot([2]*len(bilstmltc_32_n_50), bilstmltc_32_n_60, 'o', alpha=0.5, markersize=10)
axs[2,0].plot([3]*len(bilstmltc_32_n_50), bilstmltc_32_n_100, 'o', alpha=0.5, markersize=10)
axs[2,1].plot([1]*len(bilstmltc_32_n_50), bilstmltc_64_n_50, 'o', alpha=0.5, markersize=10)
axs[2,1].plot([2]*len(bilstmltc_32_n_50), bilstmltc_64_n_60, 'o', alpha=0.5, markersize=10)
axs[2,1].plot([3]*len(bilstmltc_32_n_50), bilstmltc_64_n_100, 'o', alpha=0.5, markersize=10)
axs[2,2].plot([1]*len(bilstmltc_32_n_50), bilstmltc_128_n_50, 'o', alpha=0.5, markersize=10)
axs[2,2].plot([2]*len(bilstmltc_32_n_50), bilstmltc_128_n_60, 'o', alpha=0.5, markersize=10)
axs[2,2].plot([3]*len(bilstmltc_32_n_50), bilstmltc_128_n_100, 'o', alpha=0.5, markersize=10)

# Connect the dots
for i in range(len(bilstmbtc_32_n_50)):
    axs[0,0].plot([1, 2, 3], [bilstmbtc_32_n_50[i], bilstmbtc_32_n_60[i], bilstmbtc_32_n_100[i]], '-')
    axs[0,1].plot([1, 2, 3], [bilstmbtc_64_n_50[i], bilstmbtc_64_n_60[i], bilstmbtc_64_n_100[i]], '-')
    axs[0,2].plot([1, 2, 3], [bilstmbtc_128_n_50[i], bilstmbtc_128_n_60[i], bilstmbtc_128_n_100[i]], '-')
    axs[1,0].plot([1, 2, 3], [bilstmeth_32_n_50[i], bilstmeth_32_n_60[i], bilstmeth_32_n_100[i]], '-')
    axs[1,1].plot([1, 2, 3], [bilstmeth_64_n_50[i], bilstmeth_64_n_60[i], bilstmeth_64_n_100[i]], '-')
    axs[1,2].plot([1, 2, 3], [bilstmeth_128_n_50[i], bilstmeth_128_n_60[i], bilstmeth_128_n_100[i]], '-')
    axs[2,0].plot([1, 2, 3], [bilstmltc_32_n_50[i], bilstmltc_32_n_60[i], bilstmltc_32_n_100[i]], '-')
    axs[2,1].plot([1, 2, 3], [bilstmltc_64_n_50[i], bilstmltc_64_n_60[i], bilstmltc_64_n_100[i]], '-')
    axs[2,2].plot([1, 2, 3], [bilstmltc_128_n_50[i], bilstmltc_128_n_60[i], bilstmltc_128_n_100[i]], '-')
    
labels = ['epoch 25', 'epoch 50', 'epoch 100']

# Create a list of the line objects in your figure
lines = [axs[0,0], axs[0,0].lines[1], axs[0,0].lines[2]]

# Create the legend
red_line = Line2D([0], [0], color='red', lw=1)
purple_line = Line2D([0], [0], color='purple', lw=1)
brown_line = Line2D([0], [0], color='brown', lw=1)
fig.legend([red_line, purple_line, brown_line], ['epoch 25', 'epoch 50', 'epoch 100'],loc='center', bbox_to_anchor=(0.5, 0), ncol=3)

# Show the plot
plt.show()
fig.savefig('../../Skripsi/img/bilstmUnitCompare.png', dpi=300)
