# %%
import matplotlib.pyplot as plt
import numpy as np
import pickle

with open('../Training 300/LSTM_BTC(32, 100, 50).pkl', "rb") as file_pi:
    lstm_btc = pickle.load(file_pi)
# with open('../Training 300/BiLSTM_BTC(32, 100, 50).pkl', "rb") as file_pi:
#     bilstm_btc = pickle.load(file_pi)
# with open('../Training 300/LSTM_ETH(32, 100, 50).pkl', "rb") as file_pi:
#     lstm_eth = pickle.load(file_pi)
# with open('../Training 300/BiLSTM_ETH(32, 100, 50).pkl', "rb") as file_pi:
#     bilstm_eth = pickle.load(file_pi)
# with open('../Training 300/LSTM_LTC(32, 100, 50).pkl', "rb") as file_pi:
#     lstm_ltc = pickle.load(file_pi)
# with open('../Training 300/BiLSTM_LTC(32, 100, 50).pkl', "rb") as file_pi:
#     bilstm_ltc = pickle.load(file_pi)

# %%
fig, axs = plt.subplots(ncols=3, nrows=2)
fig.set_figwidth(12)
fig.set_figheight(8)
fig.tight_layout()

axs[0,0].plot(lstm_btc['loss'])
axs[0,0].plot(lstm_btc['val_loss'])
axs[0,0].set_xlabel('LSTM BTC')
axs[0,0].set_ylabel('Value')
axs[0,1].plot(lstm_eth['loss'])
axs[0,1].plot(lstm_eth['val_loss'])
axs[0,1].set_xlabel('LSTM ETH')
axs[0,2].plot(lstm_ltc['loss'])
axs[0,2].plot(lstm_ltc['val_loss'])
axs[0,2].set_xlabel('LSTM LTC')
axs[1,0].plot(bilstm_btc['loss'])
axs[1,0].plot(bilstm_btc['val_loss'])
axs[1,0].set_xlabel('BiLSTM BTC')
axs[1,0].set_ylabel('Value')
axs[1,1].plot(bilstm_eth['loss'])
axs[1,1].plot(bilstm_eth['val_loss'])
axs[1,1].set_xlabel('BiLSTM ETH')
axs[1,2].plot(bilstm_ltc['loss'])
axs[1,2].plot(bilstm_ltc['val_loss'])
axs[1,2].set_xlabel('BiLSTM LTC')
fig.legend(['loss', 'val_loss'], loc='lower center', ncol=2, bbox_to_anchor=(0.5, -0.08))
# fig.savefig('../../Skripsi/img/lossVal_lossCompare.png', dpi=300, bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [3], line 10
#       8 axs[0,0].set_xlabel('LSTM BTC')
#       9 axs[0,0].set_ylabel('Value')
# ---> 10 axs[0,1].plot(lstm_eth['loss'])
#      11 axs[0,1].plot(lstm_eth['val_loss'])
#      12 axs[0,1].set_xlabel('LSTM ETH')
#
# NameError: name 'lstm_eth' is not defined
