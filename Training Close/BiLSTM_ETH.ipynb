# %%
from Skripsi import Preprocessing
from Skripsi import Evaluation
from Skripsi import LSTMUnit
from pandas import read_csv
from pandas import DataFrame
import numpy as np
import pandas as pd
from openpyxl.workbook import Workbook
import pickle

# %%
eth_dfd = pd.read_csv('../Dataset/Binance_ETHUSDT_1h.csv')
eth_dfd
# Out:
#                       Date     Open     High      Low    Close   Volume USDT
# 0      2022-12-31 23:00:00  1196.18  1197.43  1193.60  1196.13  7.086714e+06
# 1      2022-12-31 22:00:00  1200.09  1201.11  1193.08  1196.19  1.143952e+07
# 2      2022-12-31 21:00:00  1202.33  1203.00  1199.83  1200.10  4.643401e+06
# 3      2022-12-31 20:00:00  1202.66  1203.71  1202.30  1202.34  4.278879e+06
# 4      2022-12-31 19:00:00  1199.59  1205.61  1199.42  1202.65  7.738029e+06
# ...                    ...      ...      ...      ...      ...           ...
# 26269  2020-01-01 04:00:00   130.21   130.74   130.15   130.20  4.430067e+05
# 26270  2020-01-01 03:00:00   130.85   130.89   129.94   130.20  6.473610e+05
# 26271  2020-01-01 02:00:00   130.63   130.98   130.35   130.85  9.940256e+05
# 26272  2020-01-01 01:00:00   128.87   130.65   128.78   130.64  1.474278e+06
# 26273  2020-01-01 00:00:00   129.16   129.19   128.68   128.87  1.000930e+06
#
# [26274 rows x 6 columns]

# %%
df = Preprocessing.sort_df(eth_dfd)
df
# Out:
#          Close
# 0       128.87
# 1       130.64
# 2       130.85
# 3       130.20
# 4       130.20
# ...        ...
# 26269  1202.65
# 26270  1202.34
# 26271  1200.10
# 26272  1196.19
# 26273  1196.13
#
# [26274 rows x 1 columns]

# %%
x, scaler = Preprocessing.minmax_scale(df)
x
# Out:
# array([[0.00678935],
#        [0.00716197],
#        [0.00720618],
#        ...,
#        [0.23230718],
#        [0.23148404],
#        [0.2314714 ]])

# %%
train, test = Preprocessing.splitting_data(x)
train
# Out:
# array([[0.00678935],
#        [0.00716197],
#        [0.00720618],
#        ...,
#        [0.36294049],
#        [0.35696376],
#        [0.35310278]])

# %%
test
# Out:
# array([[0.34664396],
#        [0.34877655],
#        [0.35186281],
#        ...,
#        [0.23230718],
#        [0.23148404],
#        [0.2314714 ]])

# %%
train_X, train_y = Preprocessing.create_dataset(train,25)
test_X, test_y = Preprocessing.create_dataset(test,25)

# %%
train_X
# Out:
# array([[[0.00678935],
#         [0.00716197],
#         [0.00720618],
#         ...,
#         [0.00708408],
#         [0.00718934],
#         [0.00716829]],
#
#        [[0.00716197],
#         [0.00720618],
#         [0.00706934],
#         ...,
#         [0.00718934],
#         [0.00716829],
#         [0.00705881]],
#
#        [[0.00720618],
#         [0.00706934],
#         [0.00706934],
#         ...,
#         [0.00716829],
#         [0.00705881],
#         [0.00696829]],
#
#        ...,
#
#        [[0.39394411],
#         [0.39336939],
#         [0.38862632],
#         ...,
#         [0.36419099],
#         [0.36438046],
#         [0.36570254]],
#
#        [[0.39336939],
#         [0.38862632],
#         [0.39214836],
#         ...,
#         [0.36438046],
#         [0.36570254],
#         [0.36294049]],
#
#        [[0.38862632],
#         [0.39214836],
#         [0.38899684],
#         ...,
#         [0.36570254],
#         [0.36294049],
#         [0.35696376]]])

# %%
train_y
# Out:
# array([0.00705881, 0.00696829, 0.00683777, ..., 0.36294049, 0.35696376,
#        0.35310278])

# %%
test_X
# Out:
# array([[[0.34664396],
#         [0.34877655],
#         [0.35186281],
#         ...,
#         [0.34328823],
#         [0.34773236],
#         [0.34391769]],
#
#        [[0.34877655],
#         [0.35186281],
#         [0.34708184],
#         ...,
#         [0.34773236],
#         [0.34391769],
#         [0.34373243]],
#
#        [[0.35186281],
#         [0.34708184],
#         [0.34520188],
#         ...,
#         [0.34391769],
#         [0.34373243],
#         [0.35124808]],
#
#        ...,
#
#        [[0.23174087],
#         [0.23192192],
#         [0.23190718],
#         ...,
#         [0.23220192],
#         [0.23284401],
#         [0.23277875]],
#
#        [[0.23192192],
#         [0.23190718],
#         [0.23228402],
#         ...,
#         [0.23284401],
#         [0.23277875],
#         [0.23230718]],
#
#        [[0.23190718],
#         [0.23228402],
#         [0.23174087],
#         ...,
#         [0.23277875],
#         [0.23230718],
#         [0.23148404]]])

# %%
test_y
# Out:
# array([0.34373243, 0.35124808, 0.35062494, ..., 0.23230718, 0.23148404,
#        0.2314714 ])

# %%
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (20994, 25, 1) (20994,) (5230, 25, 1) (5230,)

# %% [markdown]
# ## Model Training

# %%
hyperparam = [(32,100,50)]

# %%
for batch, epoch, neuron in hyperparam:
    model1, bilstm1 = LSTMUnit.train_bilstm(train_X, train_y, test_X, test_y, neuron, epoch, batch)
# Out:
# Metal device set to: Apple M1
# Epoch 1/100
# 2023-05-15 11:26:22.165292: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-05-15 11:26:22.165745: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2023-05-15 11:26:22.352175: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2023-05-15 11:26:23.553301: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-05-15 11:26:23.730068: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-05-15 11:26:23.753754: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-05-15 11:26:24.584950: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-05-15 11:26:24.600593: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-05-15 11:26:37.341525: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-05-15 11:26:37.394685: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-05-15 11:26:37.404055: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 657/657 - 17s - loss: 4.8599e-04 - val_loss: 0.0011 - 17s/epoch - 26ms/step
# Epoch 2/100
# 657/657 - 13s - loss: 7.6599e-04 - val_loss: 0.0014 - 13s/epoch - 20ms/step
# Epoch 3/100
# 657/657 - 13s - loss: 9.4114e-04 - val_loss: 0.0024 - 13s/epoch - 20ms/step
# Epoch 4/100
# 657/657 - 13s - loss: 0.0011 - val_loss: 0.0030 - 13s/epoch - 20ms/step
# Epoch 5/100
# 657/657 - 13s - loss: 0.0011 - val_loss: 0.0030 - 13s/epoch - 20ms/step
# Epoch 6/100
# 657/657 - 13s - loss: 0.0010 - val_loss: 0.0026 - 13s/epoch - 20ms/step
# Epoch 7/100
# 657/657 - 13s - loss: 9.1907e-04 - val_loss: 0.0021 - 13s/epoch - 20ms/step
# Epoch 8/100
# 657/657 - 13s - loss: 7.5316e-04 - val_loss: 0.0015 - 13s/epoch - 20ms/step
# Epoch 9/100
# 657/657 - 13s - loss: 6.0199e-04 - val_loss: 0.0011 - 13s/epoch - 20ms/step
# Epoch 10/100
# 657/657 - 13s - loss: 4.7657e-04 - val_loss: 7.3322e-04 - 13s/epoch - 20ms/step
# Epoch 11/100
# 657/657 - 13s - loss: 3.9653e-04 - val_loss: 5.2250e-04 - 13s/epoch - 20ms/step
# Epoch 12/100
# 657/657 - 13s - loss: 3.3994e-04 - val_loss: 3.9893e-04 - 13s/epoch - 20ms/step
# Epoch 13/100
# 657/657 - 13s - loss: 3.0448e-04 - val_loss: 3.2565e-04 - 13s/epoch - 20ms/step
# Epoch 14/100
# 657/657 - 13s - loss: 2.8002e-04 - val_loss: 2.8180e-04 - 13s/epoch - 20ms/step
# Epoch 15/100
# 657/657 - 13s - loss: 2.6039e-04 - val_loss: 2.5020e-04 - 13s/epoch - 20ms/step
# Epoch 16/100
# 657/657 - 13s - loss: 2.4300e-04 - val_loss: 2.2992e-04 - 13s/epoch - 20ms/step
# Epoch 17/100
# 657/657 - 13s - loss: 2.2914e-04 - val_loss: 2.0637e-04 - 13s/epoch - 20ms/step
# Epoch 18/100
# 657/657 - 13s - loss: 2.1247e-04 - val_loss: 1.8325e-04 - 13s/epoch - 20ms/step
# Epoch 19/100
# 657/657 - 13s - loss: 1.9831e-04 - val_loss: 1.6168e-04 - 13s/epoch - 20ms/step
# Epoch 20/100
# 657/657 - 14s - loss: 1.8213e-04 - val_loss: 1.4042e-04 - 14s/epoch - 21ms/step
# Epoch 21/100
# 657/657 - 14s - loss: 1.6753e-04 - val_loss: 1.2160e-04 - 14s/epoch - 21ms/step
# Epoch 22/100
# 657/657 - 14s - loss: 1.5450e-04 - val_loss: 1.0913e-04 - 14s/epoch - 21ms/step
# Epoch 23/100
# 657/657 - 14s - loss: 1.4329e-04 - val_loss: 9.3120e-05 - 14s/epoch - 21ms/step
# Epoch 24/100
# 657/657 - 14s - loss: 1.3196e-04 - val_loss: 8.3925e-05 - 14s/epoch - 21ms/step
# Epoch 25/100
# 657/657 - 14s - loss: 1.2297e-04 - val_loss: 7.4219e-05 - 14s/epoch - 21ms/step
# Epoch 26/100
# 657/657 - 14s - loss: 1.1338e-04 - val_loss: 6.5883e-05 - 14s/epoch - 21ms/step
# Epoch 27/100
# 657/657 - 14s - loss: 1.0638e-04 - val_loss: 6.1991e-05 - 14s/epoch - 21ms/step
# Epoch 28/100
# 657/657 - 14s - loss: 1.0140e-04 - val_loss: 5.6738e-05 - 14s/epoch - 21ms/step
# Epoch 29/100
# 657/657 - 14s - loss: 9.7019e-05 - val_loss: 5.8546e-05 - 14s/epoch - 21ms/step
# Epoch 30/100
# 657/657 - 14s - loss: 9.6545e-05 - val_loss: 5.6799e-05 - 14s/epoch - 21ms/step
# Epoch 31/100
# 657/657 - 14s - loss: 9.4637e-05 - val_loss: 5.7677e-05 - 14s/epoch - 21ms/step
# Epoch 32/100
# 657/657 - 14s - loss: 9.3850e-05 - val_loss: 5.2881e-05 - 14s/epoch - 21ms/step
# Epoch 33/100
# 657/657 - 14s - loss: 9.1407e-05 - val_loss: 5.2096e-05 - 14s/epoch - 21ms/step
# Epoch 34/100
# 657/657 - 14s - loss: 9.0164e-05 - val_loss: 4.7286e-05 - 14s/epoch - 21ms/step
# Epoch 35/100
# 657/657 - 14s - loss: 8.7429e-05 - val_loss: 4.6100e-05 - 14s/epoch - 21ms/step
# Epoch 36/100
# 657/657 - 14s - loss: 8.6433e-05 - val_loss: 4.2546e-05 - 14s/epoch - 22ms/step
# Epoch 37/100
# 657/657 - 14s - loss: 8.5158e-05 - val_loss: 3.9427e-05 - 14s/epoch - 22ms/step
# Epoch 38/100
# 657/657 - 14s - loss: 8.3405e-05 - val_loss: 3.5290e-05 - 14s/epoch - 21ms/step
# Epoch 39/100
# 657/657 - 15s - loss: 8.1520e-05 - val_loss: 3.2736e-05 - 15s/epoch - 22ms/step
# Epoch 40/100
# 657/657 - 15s - loss: 8.0818e-05 - val_loss: 3.0592e-05 - 15s/epoch - 23ms/step
# Epoch 41/100
# 657/657 - 14s - loss: 8.0641e-05 - val_loss: 2.9351e-05 - 14s/epoch - 22ms/step
# Epoch 42/100
# 657/657 - 14s - loss: 8.1041e-05 - val_loss: 2.7084e-05 - 14s/epoch - 22ms/step
# Epoch 43/100
# 657/657 - 14s - loss: 8.0708e-05 - val_loss: 2.4964e-05 - 14s/epoch - 22ms/step
# Epoch 44/100
# 657/657 - 14s - loss: 8.0195e-05 - val_loss: 2.2970e-05 - 14s/epoch - 22ms/step
# Epoch 45/100
# 657/657 - 15s - loss: 7.9813e-05 - val_loss: 2.2208e-05 - 15s/epoch - 22ms/step
# Epoch 46/100
# 657/657 - 14s - loss: 8.0624e-05 - val_loss: 2.0545e-05 - 14s/epoch - 22ms/step
# Epoch 47/100
# 657/657 - 14s - loss: 8.0090e-05 - val_loss: 1.8945e-05 - 14s/epoch - 22ms/step
# Epoch 48/100
# 657/657 - 14s - loss: 7.8926e-05 - val_loss: 1.7166e-05 - 14s/epoch - 22ms/step
# Epoch 49/100
# 657/657 - 14s - loss: 7.7240e-05 - val_loss: 1.5918e-05 - 14s/epoch - 22ms/step
# Epoch 50/100
# 657/657 - 14s - loss: 7.6084e-05 - val_loss: 1.5030e-05 - 14s/epoch - 22ms/step
# Epoch 51/100
# 657/657 - 14s - loss: 7.5238e-05 - val_loss: 1.4411e-05 - 14s/epoch - 22ms/step
# Epoch 52/100
# 657/657 - 14s - loss: 7.4515e-05 - val_loss: 1.3824e-05 - 14s/epoch - 22ms/step
# Epoch 53/100
# 657/657 - 14s - loss: 7.3606e-05 - val_loss: 1.3344e-05 - 14s/epoch - 22ms/step
# Epoch 54/100
# 657/657 - 14s - loss: 7.2684e-05 - val_loss: 1.3013e-05 - 14s/epoch - 22ms/step
# Epoch 55/100
# 657/657 - 14s - loss: 7.1997e-05 - val_loss: 1.2760e-05 - 14s/epoch - 22ms/step
# Epoch 56/100
# 657/657 - 14s - loss: 7.1271e-05 - val_loss: 1.2580e-05 - 14s/epoch - 22ms/step
# Epoch 57/100
# 657/657 - 14s - loss: 7.0477e-05 - val_loss: 1.2375e-05 - 14s/epoch - 22ms/step
# Epoch 58/100
# 657/657 - 14s - loss: 6.9549e-05 - val_loss: 1.2180e-05 - 14s/epoch - 22ms/step
# Epoch 59/100
# 657/657 - 14s - loss: 6.8635e-05 - val_loss: 1.2054e-05 - 14s/epoch - 22ms/step
# Epoch 60/100
# 657/657 - 14s - loss: 6.7984e-05 - val_loss: 1.1964e-05 - 14s/epoch - 22ms/step
# Epoch 61/100
# 657/657 - 14s - loss: 6.7450e-05 - val_loss: 1.1903e-05 - 14s/epoch - 22ms/step
# Epoch 62/100
# 657/657 - 14s - loss: 6.6924e-05 - val_loss: 1.1851e-05 - 14s/epoch - 22ms/step
# Epoch 63/100
# 657/657 - 15s - loss: 6.6320e-05 - val_loss: 1.1794e-05 - 15s/epoch - 22ms/step
# Epoch 64/100
# 657/657 - 14s - loss: 6.5786e-05 - val_loss: 1.1808e-05 - 14s/epoch - 22ms/step
# Epoch 65/100
# 657/657 - 14s - loss: 6.5571e-05 - val_loss: 1.1777e-05 - 14s/epoch - 22ms/step
# Epoch 66/100
# 657/657 - 15s - loss: 6.4833e-05 - val_loss: 1.1758e-05 - 15s/epoch - 22ms/step
# Epoch 67/100
# 657/657 - 15s - loss: 6.4173e-05 - val_loss: 1.1734e-05 - 15s/epoch - 22ms/step
# Epoch 68/100
# 657/657 - 15s - loss: 6.3570e-05 - val_loss: 1.1713e-05 - 15s/epoch - 22ms/step
# Epoch 69/100
# 657/657 - 15s - loss: 6.3046e-05 - val_loss: 1.1717e-05 - 15s/epoch - 22ms/step
# Epoch 70/100
# 657/657 - 15s - loss: 6.2719e-05 - val_loss: 1.1732e-05 - 15s/epoch - 22ms/step
# Epoch 71/100
# 657/657 - 14s - loss: 6.2309e-05 - val_loss: 1.1764e-05 - 14s/epoch - 22ms/step
# Epoch 72/100
# 657/657 - 15s - loss: 6.1988e-05 - val_loss: 1.1807e-05 - 15s/epoch - 22ms/step
# Epoch 73/100
# 657/657 - 15s - loss: 6.1441e-05 - val_loss: 1.1861e-05 - 15s/epoch - 22ms/step
# Epoch 74/100
# 657/657 - 14s - loss: 6.0827e-05 - val_loss: 1.1876e-05 - 14s/epoch - 22ms/step
# Epoch 75/100
# 657/657 - 15s - loss: 6.0405e-05 - val_loss: 1.1908e-05 - 15s/epoch - 22ms/step
# Epoch 76/100
# 657/657 - 15s - loss: 5.9908e-05 - val_loss: 1.1944e-05 - 15s/epoch - 22ms/step
# Epoch 77/100
# 657/657 - 15s - loss: 5.9658e-05 - val_loss: 1.2008e-05 - 15s/epoch - 22ms/step
# Epoch 78/100
# 657/657 - 15s - loss: 5.9272e-05 - val_loss: 1.2097e-05 - 15s/epoch - 22ms/step
# Epoch 79/100
# 657/657 - 14s - loss: 5.8637e-05 - val_loss: 1.2169e-05 - 14s/epoch - 22ms/step
# Epoch 80/100
# 657/657 - 15s - loss: 5.8047e-05 - val_loss: 1.2228e-05 - 15s/epoch - 22ms/step
# Epoch 81/100
# 657/657 - 15s - loss: 5.7571e-05 - val_loss: 1.2253e-05 - 15s/epoch - 22ms/step
# Epoch 82/100
# 657/657 - 15s - loss: 5.7234e-05 - val_loss: 1.2293e-05 - 15s/epoch - 22ms/step
# Epoch 83/100
# 657/657 - 14s - loss: 5.6926e-05 - val_loss: 1.2382e-05 - 14s/epoch - 22ms/step
# Epoch 84/100
# 657/657 - 15s - loss: 5.6524e-05 - val_loss: 1.2471e-05 - 15s/epoch - 22ms/step
# Epoch 85/100
# 657/657 - 15s - loss: 5.6139e-05 - val_loss: 1.2561e-05 - 15s/epoch - 22ms/step
# Epoch 86/100
# 657/657 - 15s - loss: 5.5655e-05 - val_loss: 1.2639e-05 - 15s/epoch - 22ms/step
# Epoch 87/100
# 657/657 - 15s - loss: 5.5294e-05 - val_loss: 1.2715e-05 - 15s/epoch - 22ms/step
# Epoch 88/100
# 657/657 - 15s - loss: 5.4979e-05 - val_loss: 1.2782e-05 - 15s/epoch - 22ms/step
# Epoch 89/100
# 657/657 - 15s - loss: 5.4642e-05 - val_loss: 1.2876e-05 - 15s/epoch - 22ms/step
# Epoch 90/100
# 657/657 - 15s - loss: 5.4254e-05 - val_loss: 1.2960e-05 - 15s/epoch - 23ms/step
# Epoch 91/100
# 657/657 - 15s - loss: 5.3955e-05 - val_loss: 1.3042e-05 - 15s/epoch - 22ms/step
# Epoch 92/100
# 657/657 - 15s - loss: 5.3598e-05 - val_loss: 1.3120e-05 - 15s/epoch - 22ms/step
# Epoch 93/100
# 657/657 - 15s - loss: 5.3280e-05 - val_loss: 1.3225e-05 - 15s/epoch - 22ms/step
# Epoch 94/100
# 657/657 - 15s - loss: 5.2983e-05 - val_loss: 1.3302e-05 - 15s/epoch - 22ms/step
# Epoch 95/100
# 657/657 - 15s - loss: 5.2762e-05 - val_loss: 1.3383e-05 - 15s/epoch - 22ms/step
# Epoch 96/100
# 657/657 - 15s - loss: 5.2407e-05 - val_loss: 1.3466e-05 - 15s/epoch - 22ms/step
# Epoch 97/100
# 657/657 - 15s - loss: 5.2083e-05 - val_loss: 1.3547e-05 - 15s/epoch - 22ms/step
# Epoch 98/100
# 657/657 - 15s - loss: 5.1828e-05 - val_loss: 1.3626e-05 - 15s/epoch - 23ms/step
# Epoch 99/100
# 657/657 - 15s - loss: 5.1652e-05 - val_loss: 1.3710e-05 - 15s/epoch - 23ms/step
# Epoch 100/100
# 657/657 - 15s - loss: 5.1478e-05 - val_loss: 1.3838e-05 - 15s/epoch - 23ms/step

# %%
i=0
# make a prediction
test_x2 = test_X
yhat = LSTMUnit.predict(test_x2, model1)
inv_yhat = Preprocessing.inverse_scaler(yhat, scaler)
inv_y = Preprocessing.inverse_scaler(test_y.reshape(-1,1), scaler)
print(hyperparam[i])
print("Epoch: "+ str(bilstm1.params['epochs']))
print("Neurons: "+str(model1.layers[0].layer.units))
i = i+1
print('RMSE')
print(Evaluation.rmse(inv_y,inv_yhat))
print('MAE')
print(Evaluation.mae(inv_y,inv_yhat))
print('MAPE')
print(Evaluation.mape(inv_y,inv_yhat))
LSTMUnit.save_model(model1, 1, 'ETH',hyperparam[0])
with open('BiLSTM_ETH'+str(hyperparam[0])+'.pkl', 'wb') as f:
    pickle.dump(bilstm1.history, f)
# Out:
# 2023-05-15 11:50:04.816389: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-05-15 11:50:04.887665: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-05-15 11:50:04.898699: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 164/164 [==============================] - 2s 10ms/step
# (32, 100, 50)
# Epoch: 100
# Neurons: 50
# RMSE
# 17.67003938132171
# MAE
# 14.230177656418066
# MAPE
# 1.0076109495806385
