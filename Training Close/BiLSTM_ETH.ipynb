# %%
from Skripsi import Preprocessing
from Skripsi import Evaluation
from Skripsi import LSTMUnit
from pandas import read_csv
from pandas import DataFrame
import numpy as np
import pandas as pd
from openpyxl.workbook import Workbook
import pickle

# %%
eth_dfd = pd.read_csv('../Dataset/Binance_ETHUSDT_1h.csv')
eth_dfd
# Out:
#                       Date     Open     High      Low    Close   Volume USDT
# 0      2022-12-31 23:00:00  1196.18  1197.43  1193.60  1196.13  7.086714e+06
# 1      2022-12-31 22:00:00  1200.09  1201.11  1193.08  1196.19  1.143952e+07
# 2      2022-12-31 21:00:00  1202.33  1203.00  1199.83  1200.10  4.643401e+06
# 3      2022-12-31 20:00:00  1202.66  1203.71  1202.30  1202.34  4.278879e+06
# 4      2022-12-31 19:00:00  1199.59  1205.61  1199.42  1202.65  7.738029e+06
# ...                    ...      ...      ...      ...      ...           ...
# 26269  2020-01-01 04:00:00   130.21   130.74   130.15   130.20  4.430067e+05
# 26270  2020-01-01 03:00:00   130.85   130.89   129.94   130.20  6.473610e+05
# 26271  2020-01-01 02:00:00   130.63   130.98   130.35   130.85  9.940256e+05
# 26272  2020-01-01 01:00:00   128.87   130.65   128.78   130.64  1.474278e+06
# 26273  2020-01-01 00:00:00   129.16   129.19   128.68   128.87  1.000930e+06
#
# [26274 rows x 6 columns]

# %%
df = Preprocessing.sort_df(eth_dfd)
df
# Out:
#          Close
# 0       128.87
# 1       130.64
# 2       130.85
# 3       130.20
# 4       130.20
# ...        ...
# 26269  1202.65
# 26270  1202.34
# 26271  1200.10
# 26272  1196.19
# 26273  1196.13
#
# [26274 rows x 1 columns]

# %%
x, scaler = Preprocessing.minmax_scale(df)
x
# Out:
# array([[0.00678935],
#        [0.00716197],
#        [0.00720618],
#        ...,
#        [0.23230718],
#        [0.23148404],
#        [0.2314714 ]])

# %%
train, test = Preprocessing.splitting_data(x)
train
# Out:
# array([[0.00678935],
#        [0.00716197],
#        [0.00720618],
#        ...,
#        [0.36294049],
#        [0.35696376],
#        [0.35310278]])

# %%
test
# Out:
# array([[0.34664396],
#        [0.34877655],
#        [0.35186281],
#        ...,
#        [0.23230718],
#        [0.23148404],
#        [0.2314714 ]])

# %%
train_X, train_y = Preprocessing.create_dataset(train,25)
test_X, test_y = Preprocessing.create_dataset(test,25)

# %%
train_X
# Out:
# array([[[0.00678935],
#         [0.00716197],
#         [0.00720618],
#         ...,
#         [0.00708408],
#         [0.00718934],
#         [0.00716829]],
#
#        [[0.00716197],
#         [0.00720618],
#         [0.00706934],
#         ...,
#         [0.00718934],
#         [0.00716829],
#         [0.00705881]],
#
#        [[0.00720618],
#         [0.00706934],
#         [0.00706934],
#         ...,
#         [0.00716829],
#         [0.00705881],
#         [0.00696829]],
#
#        ...,
#
#        [[0.39394411],
#         [0.39336939],
#         [0.38862632],
#         ...,
#         [0.36419099],
#         [0.36438046],
#         [0.36570254]],
#
#        [[0.39336939],
#         [0.38862632],
#         [0.39214836],
#         ...,
#         [0.36438046],
#         [0.36570254],
#         [0.36294049]],
#
#        [[0.38862632],
#         [0.39214836],
#         [0.38899684],
#         ...,
#         [0.36570254],
#         [0.36294049],
#         [0.35696376]]])

# %%
train_y
# Out:
# array([0.00705881, 0.00696829, 0.00683777, ..., 0.36294049, 0.35696376,
#        0.35310278])

# %%
test_X
# Out:
# array([[[0.34664396],
#         [0.34877655],
#         [0.35186281],
#         ...,
#         [0.34328823],
#         [0.34773236],
#         [0.34391769]],
#
#        [[0.34877655],
#         [0.35186281],
#         [0.34708184],
#         ...,
#         [0.34773236],
#         [0.34391769],
#         [0.34373243]],
#
#        [[0.35186281],
#         [0.34708184],
#         [0.34520188],
#         ...,
#         [0.34391769],
#         [0.34373243],
#         [0.35124808]],
#
#        ...,
#
#        [[0.23174087],
#         [0.23192192],
#         [0.23190718],
#         ...,
#         [0.23220192],
#         [0.23284401],
#         [0.23277875]],
#
#        [[0.23192192],
#         [0.23190718],
#         [0.23228402],
#         ...,
#         [0.23284401],
#         [0.23277875],
#         [0.23230718]],
#
#        [[0.23190718],
#         [0.23228402],
#         [0.23174087],
#         ...,
#         [0.23277875],
#         [0.23230718],
#         [0.23148404]]])

# %%
test_y
# Out:
# array([0.34373243, 0.35124808, 0.35062494, ..., 0.23230718, 0.23148404,
#        0.2314714 ])

# %%
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (20994, 25, 1) (20994,) (5230, 25, 1) (5230,)

# %% [markdown]
# ## Model Training

# %%
hyperparam = [(32,100,50)]

# %%
for batch, epoch, neuron in hyperparam:
    model1, bilstm1 = LSTMUnit.train_bilstm(train_X, train_y, test_X, test_y, neuron, epoch, batch)
# Out:
# Metal device set to: Apple M1
# Epoch 1/100
# 2023-05-27 12:02:51.685763: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-05-27 12:02:51.685872: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2023-05-27 12:02:51.884984: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2023-05-27 12:02:53.532762: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-05-27 12:02:53.736842: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-05-27 12:02:53.768393: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-05-27 12:02:55.654733: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-05-27 12:02:55.671984: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-05-27 12:03:12.929787: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-05-27 12:03:12.998735: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-05-27 12:03:13.013851: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 657/657 - 24s - loss: 4.9279e-04 - val_loss: 0.0012 - 24s/epoch - 36ms/step
# Epoch 2/100
# 657/657 - 18s - loss: 7.7010e-04 - val_loss: 0.0015 - 18s/epoch - 27ms/step
# Epoch 3/100
# 657/657 - 19s - loss: 9.3036e-04 - val_loss: 0.0024 - 19s/epoch - 29ms/step
# Epoch 4/100
# 657/657 - 19s - loss: 0.0011 - val_loss: 0.0031 - 19s/epoch - 29ms/step
# Epoch 5/100
# 657/657 - 19s - loss: 0.0011 - val_loss: 0.0030 - 19s/epoch - 29ms/step
# Epoch 6/100
# 657/657 - 19s - loss: 0.0010 - val_loss: 0.0026 - 19s/epoch - 30ms/step
# Epoch 7/100
# 657/657 - 20s - loss: 9.0707e-04 - val_loss: 0.0020 - 20s/epoch - 30ms/step
# Epoch 8/100
# 657/657 - 19s - loss: 7.3023e-04 - val_loss: 0.0015 - 19s/epoch - 30ms/step
# Epoch 9/100
# 657/657 - 20s - loss: 5.8077e-04 - val_loss: 0.0010 - 20s/epoch - 30ms/step
# Epoch 10/100
# 657/657 - 19s - loss: 4.6116e-04 - val_loss: 7.0033e-04 - 19s/epoch - 30ms/step
# Epoch 11/100
# 657/657 - 20s - loss: 3.7832e-04 - val_loss: 4.9848e-04 - 20s/epoch - 30ms/step
# Epoch 12/100
# 657/657 - 20s - loss: 3.2579e-04 - val_loss: 3.8131e-04 - 20s/epoch - 30ms/step
# Epoch 13/100
# 657/657 - 18s - loss: 2.9193e-04 - val_loss: 3.1360e-04 - 18s/epoch - 27ms/step
# Epoch 14/100
# 657/657 - 17s - loss: 2.6679e-04 - val_loss: 2.7175e-04 - 17s/epoch - 25ms/step
# Epoch 15/100
# 657/657 - 17s - loss: 2.4879e-04 - val_loss: 2.4437e-04 - 17s/epoch - 25ms/step
# Epoch 16/100
# 657/657 - 17s - loss: 2.3079e-04 - val_loss: 2.2190e-04 - 17s/epoch - 25ms/step
# Epoch 17/100
# 657/657 - 16s - loss: 2.1856e-04 - val_loss: 1.9677e-04 - 16s/epoch - 25ms/step
# Epoch 18/100
# 657/657 - 16s - loss: 2.0028e-04 - val_loss: 1.7185e-04 - 16s/epoch - 25ms/step
# Epoch 19/100
# 657/657 - 16s - loss: 1.8386e-04 - val_loss: 1.5104e-04 - 16s/epoch - 25ms/step
# Epoch 20/100
# 657/657 - 16s - loss: 1.6842e-04 - val_loss: 1.3098e-04 - 16s/epoch - 25ms/step
# Epoch 21/100
# 657/657 - 17s - loss: 1.5469e-04 - val_loss: 1.1291e-04 - 17s/epoch - 25ms/step
# Epoch 22/100
# 657/657 - 16s - loss: 1.4092e-04 - val_loss: 9.8911e-05 - 16s/epoch - 25ms/step
# Epoch 23/100
# 657/657 - 16s - loss: 1.2956e-04 - val_loss: 8.5121e-05 - 16s/epoch - 25ms/step
# Epoch 24/100
# 657/657 - 16s - loss: 1.1879e-04 - val_loss: 7.6244e-05 - 16s/epoch - 25ms/step
# Epoch 25/100
# 657/657 - 16s - loss: 1.1059e-04 - val_loss: 6.8496e-05 - 16s/epoch - 25ms/step
# Epoch 26/100
# 657/657 - 16s - loss: 1.0440e-04 - val_loss: 6.7939e-05 - 16s/epoch - 25ms/step
# Epoch 27/100
# 657/657 - 16s - loss: 1.0205e-04 - val_loss: 6.4051e-05 - 16s/epoch - 25ms/step
# Epoch 28/100
# 657/657 - 16s - loss: 9.8582e-05 - val_loss: 6.2655e-05 - 16s/epoch - 25ms/step
# Epoch 29/100
# 657/657 - 16s - loss: 9.6683e-05 - val_loss: 5.8149e-05 - 16s/epoch - 25ms/step
# Epoch 30/100
# 657/657 - 16s - loss: 9.3750e-05 - val_loss: 5.6058e-05 - 16s/epoch - 25ms/step
# Epoch 31/100
# 657/657 - 17s - loss: 9.2122e-05 - val_loss: 5.0961e-05 - 17s/epoch - 25ms/step
# Epoch 32/100
# 657/657 - 16s - loss: 8.9511e-05 - val_loss: 4.8323e-05 - 16s/epoch - 25ms/step
# Epoch 33/100
# 657/657 - 16s - loss: 8.8141e-05 - val_loss: 4.3198e-05 - 16s/epoch - 25ms/step
# Epoch 34/100
# 657/657 - 16s - loss: 8.6286e-05 - val_loss: 3.9967e-05 - 16s/epoch - 25ms/step
# Epoch 35/100
# 657/657 - 17s - loss: 8.5165e-05 - val_loss: 3.6299e-05 - 17s/epoch - 25ms/step
# Epoch 36/100
# 657/657 - 16s - loss: 8.4130e-05 - val_loss: 3.3015e-05 - 16s/epoch - 25ms/step
# Epoch 37/100
# 657/657 - 16s - loss: 8.3020e-05 - val_loss: 3.0392e-05 - 16s/epoch - 25ms/step
# Epoch 38/100
# 657/657 - 17s - loss: 8.2846e-05 - val_loss: 2.7033e-05 - 17s/epoch - 25ms/step
# Epoch 39/100
# 657/657 - 17s - loss: 8.1465e-05 - val_loss: 2.3819e-05 - 17s/epoch - 25ms/step
# Epoch 40/100
# 657/657 - 17s - loss: 8.0498e-05 - val_loss: 2.1122e-05 - 17s/epoch - 26ms/step
# Epoch 41/100
# 657/657 - 17s - loss: 7.9526e-05 - val_loss: 1.9119e-05 - 17s/epoch - 25ms/step
# Epoch 42/100
# 657/657 - 17s - loss: 7.9075e-05 - val_loss: 1.7526e-05 - 17s/epoch - 26ms/step
# Epoch 43/100
# 657/657 - 19s - loss: 7.8469e-05 - val_loss: 1.6132e-05 - 19s/epoch - 28ms/step
# Epoch 44/100
# 657/657 - 19s - loss: 7.8091e-05 - val_loss: 1.5083e-05 - 19s/epoch - 28ms/step
# Epoch 45/100
# 657/657 - 19s - loss: 7.7769e-05 - val_loss: 1.4554e-05 - 19s/epoch - 29ms/step
# Epoch 46/100
# 657/657 - 19s - loss: 7.7793e-05 - val_loss: 1.3770e-05 - 19s/epoch - 28ms/step
# Epoch 47/100
# 657/657 - 19s - loss: 7.6960e-05 - val_loss: 1.3402e-05 - 19s/epoch - 29ms/step
# Epoch 48/100
# 657/657 - 19s - loss: 7.6707e-05 - val_loss: 1.2965e-05 - 19s/epoch - 29ms/step
# Epoch 49/100
# 657/657 - 19s - loss: 7.5277e-05 - val_loss: 1.2597e-05 - 19s/epoch - 29ms/step
# Epoch 50/100
# 657/657 - 19s - loss: 7.3889e-05 - val_loss: 1.2376e-05 - 19s/epoch - 29ms/step
# Epoch 51/100
# 657/657 - 19s - loss: 7.2792e-05 - val_loss: 1.2277e-05 - 19s/epoch - 29ms/step
# Epoch 52/100
# 657/657 - 19s - loss: 7.1949e-05 - val_loss: 1.2240e-05 - 19s/epoch - 29ms/step
# Epoch 53/100
# 657/657 - 19s - loss: 7.1497e-05 - val_loss: 1.2280e-05 - 19s/epoch - 29ms/step
# Epoch 54/100
# 657/657 - 19s - loss: 7.1327e-05 - val_loss: 1.2356e-05 - 19s/epoch - 29ms/step
# Epoch 55/100
# 657/657 - 18s - loss: 7.0532e-05 - val_loss: 1.2409e-05 - 18s/epoch - 27ms/step
# Epoch 56/100
# 657/657 - 16s - loss: 6.9533e-05 - val_loss: 1.2440e-05 - 16s/epoch - 25ms/step
# Epoch 57/100
# 657/657 - 16s - loss: 6.8563e-05 - val_loss: 1.2474e-05 - 16s/epoch - 25ms/step
# Epoch 58/100
# 657/657 - 17s - loss: 6.7673e-05 - val_loss: 1.2497e-05 - 17s/epoch - 25ms/step
# Epoch 59/100
# 657/657 - 17s - loss: 6.7378e-05 - val_loss: 1.2533e-05 - 17s/epoch - 25ms/step
# Epoch 60/100
# 657/657 - 17s - loss: 6.6839e-05 - val_loss: 1.2671e-05 - 17s/epoch - 26ms/step
# Epoch 61/100
# 657/657 - 19s - loss: 6.6207e-05 - val_loss: 1.2776e-05 - 19s/epoch - 28ms/step
# Epoch 62/100
# 657/657 - 21s - loss: 6.5651e-05 - val_loss: 1.2911e-05 - 21s/epoch - 32ms/step
# Epoch 63/100
# 657/657 - 18s - loss: 6.4994e-05 - val_loss: 1.2981e-05 - 18s/epoch - 28ms/step
# Epoch 64/100
# 657/657 - 17s - loss: 6.4475e-05 - val_loss: 1.3116e-05 - 17s/epoch - 26ms/step
# Epoch 65/100
# 657/657 - 17s - loss: 6.3941e-05 - val_loss: 1.3253e-05 - 17s/epoch - 26ms/step
# Epoch 66/100
# 657/657 - 17s - loss: 6.3413e-05 - val_loss: 1.3357e-05 - 17s/epoch - 26ms/step
# Epoch 67/100
# 657/657 - 17s - loss: 6.2867e-05 - val_loss: 1.3503e-05 - 17s/epoch - 26ms/step
# Epoch 68/100
# 657/657 - 16s - loss: 6.2335e-05 - val_loss: 1.3630e-05 - 16s/epoch - 24ms/step
# Epoch 69/100
# 657/657 - 14s - loss: 6.1982e-05 - val_loss: 1.3724e-05 - 14s/epoch - 21ms/step
# Epoch 70/100
# 657/657 - 14s - loss: 6.1594e-05 - val_loss: 1.3860e-05 - 14s/epoch - 21ms/step
# Epoch 71/100
# 657/657 - 14s - loss: 6.1053e-05 - val_loss: 1.4006e-05 - 14s/epoch - 21ms/step
# Epoch 72/100
# 657/657 - 14s - loss: 6.0496e-05 - val_loss: 1.4102e-05 - 14s/epoch - 22ms/step
# Epoch 73/100
# 657/657 - 17s - loss: 6.0089e-05 - val_loss: 1.4209e-05 - 17s/epoch - 26ms/step
# Epoch 74/100
# 657/657 - 16s - loss: 5.9714e-05 - val_loss: 1.4357e-05 - 16s/epoch - 24ms/step
# Epoch 75/100
# 657/657 - 14s - loss: 5.9488e-05 - val_loss: 1.4443e-05 - 14s/epoch - 21ms/step
# Epoch 76/100
# 657/657 - 14s - loss: 5.9194e-05 - val_loss: 1.4651e-05 - 14s/epoch - 21ms/step
# Epoch 77/100
# 657/657 - 14s - loss: 5.8679e-05 - val_loss: 1.4817e-05 - 14s/epoch - 21ms/step
# Epoch 78/100
# 657/657 - 14s - loss: 5.8201e-05 - val_loss: 1.4936e-05 - 14s/epoch - 21ms/step
# Epoch 79/100
# 657/657 - 14s - loss: 5.7805e-05 - val_loss: 1.5074e-05 - 14s/epoch - 21ms/step
# Epoch 80/100
# 657/657 - 14s - loss: 5.7507e-05 - val_loss: 1.5228e-05 - 14s/epoch - 21ms/step
# Epoch 81/100
# 657/657 - 16s - loss: 5.7296e-05 - val_loss: 1.5443e-05 - 16s/epoch - 24ms/step
# Epoch 82/100
# 657/657 - 16s - loss: 5.7006e-05 - val_loss: 1.5718e-05 - 16s/epoch - 25ms/step
# Epoch 83/100
# 657/657 - 16s - loss: 5.6606e-05 - val_loss: 1.5888e-05 - 16s/epoch - 25ms/step
# Epoch 84/100
# 657/657 - 17s - loss: 5.6298e-05 - val_loss: 1.5968e-05 - 17s/epoch - 25ms/step
# Epoch 85/100
# 657/657 - 17s - loss: 5.6080e-05 - val_loss: 1.5999e-05 - 17s/epoch - 26ms/step
# Epoch 86/100
# 657/657 - 17s - loss: 5.5818e-05 - val_loss: 1.6040e-05 - 17s/epoch - 26ms/step
# Epoch 87/100
# 657/657 - 17s - loss: 5.5483e-05 - val_loss: 1.6022e-05 - 17s/epoch - 26ms/step
# Epoch 88/100
# 657/657 - 18s - loss: 5.5195e-05 - val_loss: 1.5954e-05 - 18s/epoch - 27ms/step
# Epoch 89/100
# 657/657 - 18s - loss: 5.4939e-05 - val_loss: 1.5895e-05 - 18s/epoch - 27ms/step
# Epoch 90/100
# 657/657 - 18s - loss: 5.4655e-05 - val_loss: 1.5876e-05 - 18s/epoch - 27ms/step
# Epoch 91/100
# 657/657 - 18s - loss: 5.4208e-05 - val_loss: 1.5813e-05 - 18s/epoch - 27ms/step
# Epoch 92/100
# 657/657 - 18s - loss: 5.3780e-05 - val_loss: 1.5880e-05 - 18s/epoch - 27ms/step
# Epoch 93/100
# 657/657 - 18s - loss: 5.3373e-05 - val_loss: 1.5774e-05 - 18s/epoch - 27ms/step
# Epoch 94/100
# 657/657 - 18s - loss: 5.3271e-05 - val_loss: 1.5724e-05 - 18s/epoch - 27ms/step
# Epoch 95/100
# 657/657 - 18s - loss: 5.3076e-05 - val_loss: 1.5763e-05 - 18s/epoch - 27ms/step
# Epoch 96/100
# 657/657 - 18s - loss: 5.2743e-05 - val_loss: 1.5668e-05 - 18s/epoch - 27ms/step
# Epoch 97/100
# 657/657 - 18s - loss: 5.2557e-05 - val_loss: 1.5619e-05 - 18s/epoch - 28ms/step
# Epoch 98/100
# 657/657 - 18s - loss: 5.2350e-05 - val_loss: 1.5603e-05 - 18s/epoch - 28ms/step
# Epoch 99/100
# 657/657 - 19s - loss: 5.2086e-05 - val_loss: 1.5537e-05 - 19s/epoch - 28ms/step
# Epoch 100/100
# 657/657 - 18s - loss: 5.1829e-05 - val_loss: 1.5434e-05 - 18s/epoch - 28ms/step

# %%
i=0
# make a prediction
test_x2 = test_X
yhat = LSTMUnit.predict(test_x2, model1)
inv_yhat = Preprocessing.inverse_scaler(yhat, scaler)
inv_y = Preprocessing.inverse_scaler(test_y.reshape(-1,1), scaler)
print(hyperparam[i])
print("Epoch: "+ str(bilstm1.params['epochs']))
print("Neurons: "+str(model1.layers[0].layer.units))
i = i+1
print('RMSE')
print(Evaluation.rmse(inv_y,inv_yhat))
print('MAE')
print(Evaluation.mae(inv_y,inv_yhat))
print('MAPE')
print(Evaluation.mape(inv_y,inv_yhat))
LSTMUnit.save_model(model1, 1, 'ETH',hyperparam[0])
with open('BiLSTM_ETH'+str(hyperparam[0])+'.pkl', 'wb') as f:
    pickle.dump(bilstm1.history, f)
# Out:
# 2023-05-27 12:31:33.885218: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-05-27 12:31:33.948835: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-05-27 12:31:33.961756: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 164/164 [==============================] - 2s 12ms/step
# (32, 100, 50)
# Epoch: 100
# Neurons: 50
# RMSE
# 18.66134352234677
# MAE
# 15.523202289413565
# MAPE
# 1.1127707686256174
